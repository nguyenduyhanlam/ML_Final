# %% [markdown]
# **1) Tài liệu tham khảo**
#
# ***Lý thuyết:***
#
# [1] 	Trevor Hastie, Robert Tibshirani, Jerome Friedman, 2008, The Elements of Statistical Learning: Data Mining, Inference, and Prediction (Second Edition).
#
# ***Dữ liệu:***
#
# Prostate cancer data - A study by Stamey et al. (1989)
#
# Source: http://web.stanford.edu/~hastie/ElemStatLearn/

# %% [markdown]
# **2) Chuẩn bị thư viện**

# %%
# Import necessary modules and set options
import pandas as pd
import numpy as np
import itertools

from sklearn.linear_model import LinearRegression, RidgeCV, LassoCV, ElasticNetCV, LarsCV
from sklearn.cross_decomposition import PLSRegression
from sklearn.decomposition import PCA
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV

import warnings
warnings.filterwarnings("ignore")
# Out:
#   File "<ipython-input-1-68499c813768>", line 2
#     y=Prostate[,9]
#                ^
# SyntaxError: invalid syntax

# %% [markdown]
# 3) Chuẩn bị dữ liệu

# %%
# Load data
data = pd.read_csv("prostate_data", sep = "\t")
print(data.head())

# Train-test split
y_train = np.array(data[data.train == "T"]['lpsa'])
y_test = np.array(data[data.train == "F"]['lpsa'])
X_train = np.array(data[data.train == "T"].drop(['lpsa', 'train'], axis=1))
X_test = np.array(data[data.train == "F"].drop(['lpsa', 'train'], axis=1))
